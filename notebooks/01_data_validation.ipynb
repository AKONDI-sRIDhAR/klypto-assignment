# %%
import os
import sys

# Add project root to path
PROJECT_ROOT = os.path.abspath(os.path.join(".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.data_io import load_csv

# %%
# 01. Data Validation

# %%
# Load raw files to confirm existence

# %%
spot = load_csv('data/raw/nifty_spot_5min.csv')
# Out:
# Loaded 126 rows from F:\antigravity\klypto assignment\data/raw/nifty_spot_5min.csv

# %%
fut = load_csv('data/raw/nifty_futures_raw.csv')
# Out:
# Loaded 5040 rows from F:\antigravity\klypto assignment\data/raw/nifty_futures_raw.csv

# %%
opt = load_csv('data/raw/nifty_options_raw.csv')
# Out:
# Loaded 269426 rows from F:\antigravity\klypto assignment\data/raw/nifty_options_raw.csv

# %%
print('All raw files validated.')
# Out:
# All raw files validated.
