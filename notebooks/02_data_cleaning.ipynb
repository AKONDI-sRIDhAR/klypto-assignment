# %%
import os
import sys

# Add project root to path
PROJECT_ROOT = os.path.abspath(os.path.join(".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.data_io import load_csv, save_csv

# %%
from src.cleaning import clean_spot_data, clean_futures_data, clean_options_data

# %%
# 02. Data Cleaning

# %%
# Load

# %%
spot_raw = load_csv('data/raw/nifty_spot_5min.csv')
# Out:
# Loaded 126 rows from F:\antigravity\klypto assignment\nifty-quant-research\data/raw/nifty_spot_5min.csv

# %%
fut_raw = load_csv('data/raw/nifty_futures_raw.csv')
# Out:
# Loaded 5040 rows from F:\antigravity\klypto assignment\nifty-quant-research\data/raw/nifty_futures_raw.csv

# %%
opt_raw = load_csv('data/raw/nifty_options_raw.csv')
# Out:
# Loaded 269426 rows from F:\antigravity\klypto assignment\nifty-quant-research\data/raw/nifty_options_raw.csv

# %%
# Clean

# %%
spot_clean = clean_spot_data(spot_raw)
# Out:
#   > Cleaning Spot Data...

# %%
fut_clean = clean_futures_data(fut_raw)
# Out:
#   > Cleaning Futures Data...

# %%
opt_clean = clean_options_data(opt_raw)
# Out:
#   > Cleaning Options Data...

# %%
# Save

# %%
save_csv(spot_clean, 'data/processed/nifty_spot_clean.csv')
# Out:
# Saved file: F:\antigravity\klypto assignment\nifty-quant-research\data/processed/nifty_spot_clean.csv

# %%
save_csv(fut_clean, 'data/processed/nifty_futures_clean.csv')
# Out:
# Saved file: F:\antigravity\klypto assignment\nifty-quant-research\data/processed/nifty_futures_clean.csv

# %%
save_csv(opt_clean, 'data/processed/nifty_options_clean.csv')
# Out:
# Saved file: F:\antigravity\klypto assignment\nifty-quant-research\data/processed/nifty_options_clean.csv
