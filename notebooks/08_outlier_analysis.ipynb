# %%
import os
import sys

# Add project root to path
PROJECT_ROOT = os.path.abspath(os.path.join(".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.data_io import load_csv

# %%
# 08. Outlier Analysis

# %%
df = load_csv('data/processed/nifty_features_5min.csv')
# Out:
# Loaded 126 rows from F:\antigravity\klypto assignment\nifty-quant-research\data/processed/nifty_features_5min.csv

# %%
print('Outlier Analysis Placeholder')
# Out:
# Outlier Analysis Placeholder
